# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits as pyfits
import scipy.stats as sc
# %matplotlib inline
import Jared_function as ai

# %% [markdown]
# # A

# %%
data = np.genfromtxt('wasp_4b.tsv',delimiter=';',skip_header=36)
time = data[:,0]
flux = data[:,1]
error = data[:,2]

# %%
plt.plot(time,flux)
plt.xlim(min(time),max(time)+.5)
# Out:
# (2454697.710091, 2455101.1891470002)

# %%
off = time[1:] - time[:len(time)-1]
print min(off)
timeN = time[off > .001].reshape(5,2)
print timeN
# Out:
# 0.000295999925584
# [[ 2454697.719581  2454697.746745]
#  [ 2454697.769547  2454697.869704]
#  [ 2454748.742407  2455045.899411]
#  [ 2455049.67749   2455049.919951]
#  [ 2455053.684801  2455053.929598]]

# %%
plt.scatter(time,flux)
plt.xlim(timeN[0][0],timeN[1][1])
# Out:
# (2454697.719581, 2454697.8697040002)

# %%
plt.scatter(time,flux)
plt.xlim(timeN[3][0],timeN[3][1])
# Out:
# (2455049.6774900001, 2455049.9199509998)
